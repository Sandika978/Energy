# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandika978/Energy/blob/main/Max_Energy_Produced_by_Year.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Wind Power: A Driving Force in the Changing Landscape of Electricity Generation in United States
# In the United States, wind power has emerged as a central player in this energy evolution. What started as a modest contribution to the electricity mix has grown into a substantial force, reshaping the nation's power generation narrative. Over the years, wind energy has taken significant strides, redefining the balance between sustainability, economic growth, and energy security.

# %%
## Cloning With GitHub##
# !git clone https://github.com/Sandika978/Energy.git
# Out:
# Cloning into 'Energy'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 34 (delta 11), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (34/34), 263.03 KiB | 7.51 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %% [markdown]
# A Rising Wind: From 6 Billion kWh to 380 Billion
# The growth of wind energy in the United States is nothing short of remarkable. From a modest 6 billion kilowatt-hours (kWh) in the year 2000, wind power's annual electricity generation capacity soared to a staggering 380 billion kWh by 2021. This surge in wind power installations has been instrumental in reducing the carbon footprint and advancing the transition towards cleaner energy sources. By 2022, wind turbines accounted for 10.2% of total utility-scale electricity generation in the U.S., a testament to the sector's rapid expansion. This growth trajectory reflects the commitment of various states to embrace wind power as a viable alternative, with 19 states boasting over 1,000 MW of installed capacity. Notably, Texas, Iowa, Oklahoma, Kansas, and California have emerged as pioneers, collectively generating more than half of the nation's wind energy.
#
# Data analysis of Wind Power Generation done by python below:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Pandas is a Python library used for working with data sets. It has functions for analyzing, cleaning, exploring, and manipulating data.
# NumPy can be used to perform a wide variety of mathematical operations on arrays.
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.

# %% [markdown]
# Data of Wind power Generation obtained by Kaggle. Here I have analysed data of power genertion on some states of the United States.

# %%
data='/content/drive/MyDrive/Colab Notebooks/max wind energy in us by year.csv'

# %% [markdown]
# Pandas library can read csv file.

# %%
df=pd.read_csv(data)

# %% [markdown]
# Let's know the different dependent variables (states ) and Indpendent variable (Year) from below coding:

# %%
df.head
# Out:
# <bound method NDFrame.head of     Year  wind_texas  wind_iowa  wind_illinois  wind_kansas  wind_oklahoma
# 0   2001        1187        488              0           40              0
# 1   2002        2656        920              0          466              0
# 2   2003        2569        982             16          366             54
# 3   2004        3137       1050             78          358            574
# 4   2005        4238       1647            141          425            847
# 5   2006        6671       2316            254          992           1712
# 6   2007        9007       2759            663         1152           1849
# 7   2008       16224       4081           2337         1760           2359
# 8   2009       20026       7420           2820         2862           2697
# 9   2010       26251       9170           4453         3406           3807
# 10  2011       30547      10708           6213         3720           5606
# ...

# %%
df.columns
# Out:
# Index(['Year', 'wind_texas', 'wind_iowa', 'wind_illinois', 'wind_kansas',
#        'wind_oklahoma'],
#       dtype='object')

# %% [markdown]
# Let's plot the data for the year 2001 to 2022.
# for the Five differnt states of the United States.

# %%
from matplotlib.lines import MarkerStyle
plt.plot(df['Year'], df['wind_iowa'],label='Iowa')
plt.plot(df['Year'], df['wind_texas'], label='Texsas')
plt.plot(df['Year'], df['wind_illinois'], label='Illinois')
plt.plot(df['Year'], df['wind_kansas'], label='Kansas')
plt.plot(df['Year'], df['wind_oklahoma'], label='Oklahoma')
plt.xlabel(' Years')
plt.ylabel('Wind power Generation in MW')
plt.legend()
plt.title('Wind Power Generation in US states')
plt.savefig('Wind.png')
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# These Five states Texas(33,133 MW) , Illinois(6,409 MW), Iowa (11,660 MW), Kansas (7,016 MW), and Oklahoma (9,048 MW) are most wind capacity installed at the end of year 2020, generating over half of all wind energy in the nation.
